# %%
# %matplotlib inline
import pandas as pd
import d2l.torch as d2l
import torch
from torch.nn import functional as F
from torch import nn
import numpy as np
import os
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import STL
from pandas.api.types import is_numeric_dtype
import time
from sklearn.preprocessing import StandardScaler, MinMaxScaler

torch.manual_seed(0)

# %%
dfs = pd.DataFrame()
for i in range(1, 2):
    df = pd.read_excel(f"./data/flight_data_batch{i}.xlsx")
    dfs = pd.concat([dfs, df], ignore_index=True)

# %%
for i in range(1, 4):
    df = pd.read_excel(f"./data/flight_data_batch6_part{i}.xlsx")
    dfs = pd.concat([dfs, df], ignore_index=True)

# %%
# only visualizing a portion of data
#all_data = df.iloc[:9000]


all_data = dfs.groupby("label")

normal_groups = all_data.get_group(0)
bad_groups = all_data.get_group(1)

# %%
# compare normal vs bad flights
normal_flights = normal_groups.groupby("flight_id")
normal_flights = [f for _, f in normal_flights]
bad_flights = bad_groups.groupby("flight_id")
bad_flights = [f for _, f in bad_flights]

# %%
normal_data = normal_flights[0]
bad_data = bad_flights[0]
t = normal_data["time"].iloc[:200] # time axis

normal_data = normal_data.drop(["time", "flight_id"], axis=1) # drop the time column
bad_data = bad_data.drop(["time", "flight_id"], axis=1)
column_names = list(bad_data.columns.values)

print(normal_data)

# standard norm for all columns
scaler = MinMaxScaler()
scaler.fit(normal_data)
normal_data_scaled = scaler.transform(normal_data) # scale 

scaler = MinMaxScaler()
scaler.fit(bad_data)
bad_data_scaled = scaler.transform(bad_data) # scale 

# Set general font size for matplot
plt.rcParams['font.size'] = '16'

num_graphs = normal_data_scaled.shape[1] - 1
decomped = []
for i in range(num_graphs-1):
    fig, axes = plt.subplots(4, 2, figsize=(10, 15))
        
    column_name = normal_data_scaled.columns[i]
    axes[0, 0].set_ylabel(column_name)
    axes[0, 0].plot(t, normal_data_scaled[column_name])
    axes[0, 0].plot(t, [normal_data_scaled[column_name].mean()]*len(t), color="red")
    axes[0, 0].legend(["Measured", "Fit"])
    # STL decomp
    stl = STL(normal_data_scaled[column_name], period=10)
    res = stl.fit()
    axes[1, 0].set_ylabel("Trend")
    axes[1, 0].plot(t, res.trend)
    axes[2, 0].set_ylabel("Seasonal")
    axes[2, 0].plot(t, res.seasonal)
    axes[3, 0].set_ylabel("Residual")
    axes[3, 0].plot(t, res.resid)
    axes[3, 0].set_xlabel("time")
    # decomped.append(res)
        
    axes[0, 1].set_ylabel(column_name)
    axes[0, 1].plot(t, bad_data_scaled[column_name], color="orange")
    axes[0, 1].plot(t, [bad_data_scaled[column_name].mean()]*len(t), color="black")
    axes[0, 1].legend(["Measured", "Fit"])
    # STL decomp
    stl = STL(bad_data_scaled[column_name], period=10)
    res = stl.fit()
    axes[1, 1].plot(t, res.trend, color="orange")
    axes[2, 1].plot(t, res.seasonal, color="orange")
    axes[3, 1].plot(t, res.resid, color="orange")
    axes[3, 1].set_xlabel("time")
    # Add a horizontal line divider below to separate every 4 graphs 
    fig.add_artist(plt.Line2D((0, 1), (0.08, 0.08), color='black', 
                  linewidth=5, transform=fig.transFigure))
    plt.subplots_adjust(bottom=0.15)
# Out:
#            pitch      roll       yaw     alpha    airspeed  throttle  \
# 177000  0.074685  0.340229 -0.006298  0.015654  119.048360  0.755569
# 177001 -0.251800 -0.292777 -0.008692  0.213191  119.497385  0.849527
# 177002 -1.048871  6.730652 -0.007201  0.178021  123.535633  0.775845
# 177003 -0.216982  6.336734 -0.006572  0.010546  122.637384  0.730617
# 177004 -0.129873  4.681895 -0.006745  0.265973  122.420124  0.801433
# ...          ...       ...       ...       ...         ...       ...
# 179995 -0.193651  2.387240  0.040896  1.130979  123.954421  0.810369
# 179996  0.327711 -0.219014  0.047834  1.195282  124.527685  0.737870
# 179997  0.626624 -9.886765  0.040911  1.247055  127.378963  0.795705
# 179998  0.175900  1.833760  0.044383  1.106610  123.145900  0.787944
# 179999 -0.610386  0.692142  0.057858  1.359837  123.995561  0.819800
#
#            rpm_left    rpm_right     altitude  label
# 177000  2300.943237  2185.892155     0.954629      0
# 177001  2183.598626  2230.504645     2.992694      0
# 177002  2219.039013  2288.403956     4.461454      0
# 177003  2255.173124  2204.839757     5.040143      0
# 177004  2235.619039  2208.616405     7.380967      0
# ...             ...          ...          ...    ...
# 179995  2216.566889  2192.220205  4517.409786      0
# 179996  2158.587090  2197.293002  4518.827258      0
# 179997  2262.716704  2313.972062  4519.802813      0
# 179998  2172.867559  2138.780360  4521.850741      0
# 179999  2207.172815  2139.765905  4523.431346      0
#
# [3000 rows x 10 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 28
#      25 for i in range(num_graphs-1):
#      26     fig, axes = plt.subplots(4, 2, figsize=(10, 15))
# ---> 28     column_name = normal_data_scaled.columns[i]
#      29     axes[0, 0].set_ylabel(column_name)
#      30     axes[0, 0].plot(t, normal_data_scaled[column_name])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'columns'
